# %% [markdown]
# # Welcome to Colab!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
std=pd.read_csv('StudentPerformanceFactors.csv')

# %%
std.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
std.shape
# Out:
# (6607, 20)

# %%
std.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
std.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
std['Teacher_Quality'].fillna(std['Teacher_Quality'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_535/852803666.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   std['Teacher_Quality'].fillna(std['Teacher_Quality'].mode()[0], inplace=True)

# %%
std['Parental_Education_Level'].fillna(std['Parental_Education_Level'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_535/3340581260.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   std['Parental_Education_Level'].fillna(std['Parental_Education_Level'].mode()[0], inplace=True)

# %%
std['Distance_from_Home'].fillna(std['Distance_from_Home'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_535/1814999678.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   std['Distance_from_Home'].fillna(std['Distance_from_Home'].mode()[0], inplace=True)

# %%
std.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
num_cols = std.select_dtypes(include=['number']).columns.tolist()
cat_cols = std.select_dtypes(include=['object']).columns.tolist()

# %%
std.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
#Hours_Studied

sns.histplot(std['Hours_Studied'], bins=20)
plt.show()

# %%
#Boxplot (Outliers check)

sns.boxplot(x=std['Hours_Studied'])
plt.show()

# %%
#Exam Score

sns.histplot(std['Exam_Score'], bins=20)
plt.show()

sns.boxplot(x=std['Exam_Score'])
plt.show()

# %%
sns.countplot(x='Motivation_Level', data=std)
plt.show()

# %%
std['Exam_Score'].hist()
plt.show()

# %%
sns.boxplot(x=std['Exam_Score'])
plt.show()

# %%
sns.countplot(x='Gender', data=std)
plt.show()

# %%
sns.countplot(x='School_Type', data=std)
plt.show()

# %%
sns.scatterplot(x='Hours_Studied', y='Exam_Score', data=std)
plt.show()

# %%
sns.scatterplot(x='Attendance', y='Exam_Score', data=std)
plt.show()

# %%
sns.boxplot(x='Gender', y='Exam_Score', data=std)
plt.show()

# %%
#Correlation Heatmap

corr = std.corr(numeric_only=True)

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# Outlier Detection

# %%
sns.boxplot(x=std['Hours_Studied'])
plt.show()

# %%
sns.boxplot(x=std['Attendance'])
plt.show()

# %% [markdown]
# Group Analysis

# %%
std.groupby('Gender')['Exam_Score'].mean()
# Out:
# Gender
# Female    67.244898
# Male      67.228894
# Name: Exam_Score, dtype: float64

# %%
std.groupby('School_Type')['Exam_Score'].mean()
# Out:
# School_Type
# Private    67.287705
# Public     67.212919
# Name: Exam_Score, dtype: float64

# %%
std.groupby('Motivation_Level')['Exam_Score'].mean()
# Out:
# Motivation_Level
# High      67.704321
# Low       66.752194
# Medium    67.330648
# Name: Exam_Score, dtype: float64

# %% [markdown]
# Top Students

# %%
std.sort_values(by='Exam_Score', ascending=False).head()
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 1525             27          98                  Low              Medium
# 94               18          89                 High              Medium
# 2425             23          83                 High                High
# 3579             14          90                 High                High
# 6347             28          96                 High                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 1525                        Yes            6               93
# 94                          Yes            4               73
# 2425                        Yes            4               89
# 3579                        Yes            8               86
# 6347                        Yes            4               98
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 1525              Low              No                  5          High
# ...

# %% [markdown]
# Final Insight Example

# %%
std[['Hours_Studied','Attendance','Previous_Scores','Exam_Score']].corr()
# Out:
#                  Hours_Studied  Attendance  Previous_Scores  Exam_Score
# Hours_Studied         1.000000   -0.009908         0.024846    0.445455
# Attendance           -0.009908    1.000000        -0.020186    0.581072
# Previous_Scores       0.024846   -0.020186         1.000000    0.175079
# Exam_Score            0.445455    0.581072         0.175079    1.000000
